# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/kyr_querries.csv", sep=",", on_bad_lines="skip"
)

print(df.shape)
print(df.head())
print(df.isnull().sum())
print(df["domain"].value_counts())
print(df["intent"].value_counts())
print("Duplicates:", df["query"].duplicated().sum())
df = df.drop_duplicates(subset="query")
# Out:
# (704, 3)
#                                                query  domain        intent
# 0  My company has not given me my salary for the ...  LABOUR  UNPAID_WAGES
# 1  Boss didn't pay my salary on time. It has been...  LABOUR  UNPAID_WAGES
# 2  Mujhe mera pichle 2 mahine ka salary nahi mila...  LABOUR  UNPAID_WAGES
# 3  My employer is withholding my final settlement...  LABOUR  UNPAID_WAGES
# 4  I worked overtime for weeks but my overtime pa...  LABOUR  UNPAID_WAGES
# query     0
# domain    0
# intent    0
# dtype: int64
# domain
# LABOUR      160
# CYBER       160
# WOMEN       140
# PROPERTY    123
# CONSUMER    121
# Name: count, dtype: int64
# intent
# TENANT_RIGHTS           42
# SECURITY_DEPOSIT        41
# UNPAID_WAGES            40
# WRONGFUL_TERMINATION    40
# WORKPLACE_HARASSMENT    40
# WORKING_HOURS           40
# REFUND                  40
# DEFECTIVE_PRODUCT       40
# WARRANTY                40
# ONLINE_FRAUD            40
# ACCOUNT_HACKING         40
# ...
